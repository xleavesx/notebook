# %% [markdown]
# # Title
# ## Subtitle
# 1. 1
# 2. 2
#
# `ls --help`
#
# show details
# `ls -l`
# `ls -a`all 有隐藏文件
# `ls--lh`
#
# human readable
# `ls -lh`
# `ls -l -h`
#
# `mkdir` mew file
#
# `mkdir -p`重名则不建
#
# `pwd`查询绝对路径
#
# `rm -i`delete ask
#
# `rm -r`delete file+file floder
#
# `rm-f`强制不询问直接删除，覆盖-i
#
# `rmdir`delete a empty file flider
#
# move
#
# `mv name newname`
#
# `mv name 地址`
#
# copy
#
# `cp -r A total`在某路径下有 A 文件夹，和total文件夹，把A文件夹整个复制total文件夹下
#
#
# `less <name>`看文件前面一点点
#
#
# ## version control
# ### local
# * init git
#
# `git init`
#
#
#
# * check status
#
# `git status`
#
#
# `git add taobao_time.py`
#
#
#
# use `.gitignore` with
#
# `vim`文本编辑器  `i` `a` 编辑用的
#
# `git add -A`
#
#
#
# `git commit -m 'first commit'`
#
# remowegit：`rm -rf .git`
#
#
# ### sync with remote
#
# `git remote add origin https://github.com/xxxleaf/tutorial.git`
#
# `git remote add origin-name1 https://github.com/xxxleaf/tutorial.git`多个remote
#
# * check config
# `git remote -v`
#
#
# `git push origin master`
#
# `git pull origin-name1 branch_name1`多个remote
#
# `git pull origin master`
#
# `git remote rm origin-name1` delete

# %% [markdown]
# `git clone https://github.com/xxxleaf/tutorial.git`

# %% [markdown]
# `tail /tmp/chat -f`查看chat文件最后几行，-f是每次有更新则显示出来
#
# tali看尾巴，head看头，cat看全部，less看前面的但是会打开文件看
#
# `grep xxx 文件名` 搜索文件内部 查看这个文件下面所有含有xxx的行
#
# `find / `看所有文件和文件夹，慎用
#
# `find .`看所有当前目录下文件夹
#
# `find / |grep xxx`

# %%
cp z2/Untitled.ipynb cyx@xxx.sys18.com   上传文件到网络
